# %%
from pathlib import Path
import pandas as pd

pd.set_option("display.precision", 2)

# %% [markdown]
# How many rows has the dataframe?
# How many columns has the dataframe?
# What is the percentage of non-null values in the age column?
# How many text columns has the dataframe?
# How many men and women are in the dataset?
# What is the average age of men and women? On average who is younger?
# How many matches are there for each court surface?
# Самый старый и самый молодой игрок
# Calculate average age, proportion of females and average fare per pclass.
# Who is more likely to travel alone men or women? (consider a passenger as travelling alone if he/she has neither siblings/spouse not parents/children)
# What is the most popular lastname? firstname? (name column)
#
#
#
#
#
# 1. How many matches are there for each court surface?
# 2. What is the average match duration (minutes) by surface—on which surface are matches longest?
# 3. What share of matches ended in 2, 3, or more sets (using best_of and parsing score)?
# 4. What aьe the average rankings of winners vs. losers (winner_rank, loser_rank)?
# 5. Is there a relationship between double faults (w_df, l_df) and the likelihood of winning?
# 6. Does the first-serve percentage (w_1stIn / w_svpt) affect match outcomes?
# 7. How many break points are saved on average by winners and losers (w_bpSaved, l_bpSaved)?
# 8. What are the service metric differences (aces, double faults, first-serve %) across surfaces?

# %%
from pathlib import Path
import pandas as pd

files = Path(r"D:\DATA SCIENCE NEW\tennis_matches").glob("*.csv")
dfs = (pd.read_csv(f) for f in files)       
df = pd.concat(dfs, ignore_index=True)

df
# Out:
#                             tourney_id                tourney_name surface  \
# 0                             2015-339                    Brisbane    Hard
# 1                             2015-339                    Brisbane    Hard
# 2                             2015-339                    Brisbane    Hard
# 3                             2015-339                    Brisbane    Hard
# 4                             2015-339                    Brisbane    Hard
# ...                                ...                         ...     ...
# 46653  2023-W-FC-2023-QLS-M-SVK-ITA-01  BJK Cup QLS R1: SVK vs ITA    Hard
# 46654  2023-W-FC-2023-QLS-M-SVK-ITA-01  BJK Cup QLS R1: SVK vs ITA    Hard
# 46655  2023-W-FC-2023-QLS-M-USA-AUT-01  BJK Cup QLS R1: USA vs AUT    Hard
# 46656  2023-W-FC-2023-QLS-M-USA-AUT-01  BJK Cup QLS R1: USA vs AUT    Hard
# 46657  2023-W-FC-2023-QLS-M-USA-AUT-01  BJK Cup QLS R1: USA vs AUT    Hard
#
# ...
